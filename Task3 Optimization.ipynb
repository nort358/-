# %%
import numpy as np
import scipy
import math
from scipy import optimize
from scipy.optimize import minimize
import matplotlib.pyplot as plt
def y(x):
  y=np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)
  return y
def y1(x):
  y=np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)
  return int(y)
y3=np.vectorize(y1)

x=np.linspace(1,30)
plt.plot(x,y(x))
plt.show()

#y.minimize
x0=np.arange(1,15,0.02)
#res = minimize(y,x0)
#print(res)
#x0.shape=(len(x0),)
#print(x0)
res = minimize(y,[30],method='BFGS')
print(res)
y(25.88019339)
res2=optimize.differential_evolution(y,[(1,30)])
res2
res3 =minimize(y1,[30],method='BFGS')
print('1',res3)
print(y1(30.))
x=np.linspace(1,30)
#x=np.arange(1,30,0.02)
plt.plot(x,y3(x))
plt.show()
y(26.2851381)
# Out:
#       fun: -11.898894665981285
#  hess_inv: array([[1.67932484]])
#       jac: array([2.38418579e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([25.88019339])
# 1       fun: -5
#  hess_inv: array([[1]])
#       jac: array([0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 3
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([30.])
# -5
# -11.848805065684028
